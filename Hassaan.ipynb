# %%
a = []
b = []
v = []
x = "000"
y = "00"
for i in range(0,100):
    a.append(i)
    if i < 10:
        b.append(x+str(i))
    if i >= 10 and i <=99: 
        b.append(y+str(i))
        
print("Index","",  "Address"," ","value")
for i in range (0,100):
    print (a[i],"  ", b[i])

        
    

s =int(input("enter a value you want to store in ram:"))
t = 4*s
x=0
for i in range(0,100):
    v.append(i)
    #if j is "8":
    print (a[i],"  ", b[i]," ",'P1,A1')
    x=x+1
    if x==t:
        break
# Out:
# Index  Address   value
# 0    0000
# 1    0001
# 2    0002
# 3    0003
# 4    0004
# 5    0005
# 6    0006
# 7    0007
# 8    0008
# 9    0009
# 10    0010
# 11    0011
# 12    0012
# 13    0013
# 14    0014
# 15    0015
# 16    0016
# 17    0017
# 18    0018
# 19    0019
# 20    0020
# 21    0021
# 22    0022
# 23    0023
# 24    0024
# 25    0025
# 26    0026
# 27    0027
# 28    0028
# 29    0029
# 30    0030
# 31    0031
# 32    0032
# 33    0033
# 34    0034
# 35    0035
# 36    0036
# 37    0037
# 38    0038
# 39    0039
# 40    0040
# 41    0041
# 42    0042
# 43    0043
# 44    0044
# 45    0045
# 46    0046
# 47    0047
# 48    0048
# 49    0049
# 50    0050
# 51    0051
# 52    0052
# 53    0053
# 54    0054
# 55    0055
# 56    0056
# 57    0057
# 58    0058
# 59    0059
# 60    0060
# 61    0061
# 62    0062
# 63    0063
# 64    0064
# 65    0065
# 66    0066
# 67    0067
# 68    0068
# 69    0069
# 70    0070
# 71    0071
# 72    0072
# 73    0073
# 74    0074
# ...

# %%
#num = int(input("Enter your Array length"))
#a =  4 * num
#b = 0000

# %%
#program =input("Enter your program  number  :" )
#>>> num =int(input("list of  lenght  :" ))
#>>> my_list = [num]

#print(program)



#>>> id(my_list)

# %%
#>>> num =int(input("list of  lenght  :" ))

#>>> num1 = int(input("enter your number1 :"))
#>>> num2 = int(input("enter your number2 :" ))
#>>> num3 = int(input("enter your number3 : "))
#>>> num4 = int(input("enter your number4 :"))

#arr = [num]

#arr[0]=num1
#arr[1]=num2
#arr[2]=num3
#arr[3]=num4

#s1= id(arr[0])
#s2= id(arr[1])
#s3= id(arr[2])
#s4= id(arr[3])

#print("address 1 is ",s1)
#print("address 2 is ",s2)
#print("address 3 is ",s3)
#print("address 4 is ",s4)

# %%
#class Node :
 #   def__init__(self,key):
  #      self.left = None
   #     self.right = None
    #    self.val = key
        
#def insert(root,node):
 #   if root is None:
  #      root = node 
   # else:
    #    if root.val < node.val:
     #       root.right = node
      #      
       # else:
        #    insert (root.right,node)
         #   if root .left is None:
          #      root.left = node
           # else:
            #    insert(root.left,node)
                
#def inorder(root):
 #   if root:
   #     inorder(root.left)
    #    print (root.right)
#def minvalue(node):
 #   current = node 
  #  while(cuurent.left is not None)
  #    current = current.left
   # return current
        
#r = node(50)
#insert(r,node(30))
#insert(r,node(20))
#insert(r,node(10))
#insert(r,node(60))
#inorder(r)
#print(minvalue(r))

# %% [markdown]
# arr=[i for i in range(9)]
#
# arr1=
