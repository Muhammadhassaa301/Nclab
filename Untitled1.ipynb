# %%
b=[]
def p1A1(val,numb):
    for numb in range(0,10):
        print("p1A1",b.append(numb))
    
s=p1A1(input('enter any value'),int(input('enter the number'))
print(s)

# %%
s=input("enter any program nuber")
print(s)

# %%
a = []
b = []
v = []
x = "000"
y = "00"
for i in range(0,100):
    a.append(i)
    if i < 10:
        b.append(x+str(i))
    if i >= 10 and i <=99: 
        b.append(y+str(i))
        
print("Index","",  "Address"," ","value")
for i in range (0,100):
    print (a[i],"  ", b[i])
    
    
    
s=input("enter program and num")
# plal(50)
a=s[5]
t=a[0:5]
z=int(t)
o= z*4
x=0
for i in range(0,100):
    v.append(i)
    #if j is "8:

    print(a,"  ", b[i]," ",'P1,A1')
    x=x+1
    if x==o:
        break
# Out:
# Index  Address   value
# 0    0000
# 1    0001
# 2    0002
# 3    0003
# 4    0004
# 5    0005
# 6    0006
# 7    0007
# 8    0008
# 9    0009
# 10    0010
# 11    0011
# 12    0012
# 13    0013
# 14    0014
# 15    0015
# 16    0016
# 17    0017
# 18    0018
# 19    0019
# 20    0020
# 21    0021
# 22    0022
# 23    0023
# 24    0024
# 25    0025
# 26    0026
# 27    0027
# 28    0028
# 29    0029
# 30    0030
# 31    0031
# 32    0032
# 33    0033
# 34    0034
# 35    0035
# 36    0036
# 37    0037
# 38    0038
# 39    0039
# 40    0040
# 41    0041
# 42    0042
# 43    0043
# 44    0044
# 45    0045
# 46    0046
# 47    0047
# 48    0048
# 49    0049
# 50    0050
# 51    0051
# 52    0052
# 53    0053
# 54    0054
# 55    0055
# 56    0056
# 57    0057
# 58    0058
# 59    0059
# 60    0060
# 61    0061
# 62    0062
# 63    0063
# 64    0064
# 65    0065
# 66    0066
# 67    0067
# 68    0068
# 69    0069
# 70    0070
# 71    0071
# 72    0072
# 73    0073
# 74    0074
# ...

# %%
s=input('enter any word which you want to search')
a=s[5]
print(a)
t=a[0:5]
b=int(t)
multi=4*b
print(multi)

for i in range(0,100):
    print(multi)
# Out:
# enter any word which you want to searchp1A1(5)
# 5
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20

# %%
a=[]
b=[]

hack=input('any name which you want to display at RAM')

for i in range(0,100):
    ytr=a.append('hack')
    print('a',ytr)
    
for y in range(0,100):
    t=b.append(hack)
    print('y',t)
# Out:
# any name which you want to display at RAMataf
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# a None
# y None
# y None
# y None
# y None
# y None
# ...
